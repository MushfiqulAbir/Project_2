# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)



data = pd.read_csv('pizza_data.csv')

print(data)
# Out:
#                Company                                         Pizza Name  \
# 0       Domino's Pizza                                        Hand Tossed
# 1       Domino's Pizza                                        Hand Tossed
# 2       Domino's Pizza                                        Hand Tossed
# 3       Domino's Pizza                                       Handmade Pan
# 4       Domino's Pizza                                 Crunchy Thin Crust
# 5       Domino's Pizza                                 Crunchy Thin Crust
# 6       Domino's Pizza                                 Crunchy Thin Crust
# 7       Domino's Pizza                                     Brooklyn Style
# 8       Domino's Pizza                                     Brooklyn Style
# 9       Domino's Pizza                                  Gluten Free Crust
# 10      Domino's Pizza         Spinach & Feta (Hand Tossed or Thin Crust)
# 11      Domino's Pizza  Spinach & Feta (Hand Tossed, Handmade Pan or T...
# ...

# %%
#Print the all titles of the columns

titles = list(data.columns)
print(titles)
# Out:
# ['Company', 'Pizza Name', 'Type', 'Size', 'Price']

# %%
#Rearrange the columns 1 and 4
titles[1],titles[4] = titles[4],titles[1]
print(titles)
# Out:
# ['Company', 'Type', 'Price', 'Size', 'Pizza Name']

# %%
#print the rearranged columns for a better view
data = data[titles]
print(data)
# Out:
#                Company                   Type   Price           Size  \
# 0       Domino's Pizza          Cheeses Pizza   $5.99    Small (10")
# 1       Domino's Pizza          Cheeses Pizza   $7.99   Medium (12")
# 2       Domino's Pizza          Cheeses Pizza   $9.99    Large (14")
# 3       Domino's Pizza          Cheeses Pizza   $7.99   Medium (12")
# 4       Domino's Pizza          Cheeses Pizza   $5.99    Small (10")
# 5       Domino's Pizza          Cheeses Pizza   $7.99   Medium (12")
# 6       Domino's Pizza          Cheeses Pizza   $9.99    Large (14")
# 7       Domino's Pizza          Cheeses Pizza   $9.99    Large (14")
# 8       Domino's Pizza          Cheeses Pizza  $11.99  X-Large (16")
# 9       Domino's Pizza          Cheeses Pizza   $8.99    Small (10")
# 10      Domino's Pizza       Specialty Pizzas  $11.99    Small (10")
# 11      Domino's Pizza       Specialty Pizzas  $13.99   Medium (12")
# 12      Domino's Pizza       Specialty Pizzas  $15.99    Large (14")
# ...
